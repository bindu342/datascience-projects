# %% [markdown]
# <a href="https://colab.research.google.com/github/bindu342/datascience-projects/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn
import matplotlib.pyplot as plt
df = seaborn.load_dataset('tips')
seaborn.pairplot(df,hue = 'size')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('tips')
sns.pairplot(df, hue="size", palette="husl")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('tips')
sns.pairplot(df, diag_kind="kde")
plt.show()

# %%
sns.pairplot(df, kind='reg')
plt.show()

# %%
sns.pairplot(df, hue='sex', markers=["o", "s"])
plt.show()

# %%
g = sns.pairplot(df, hue='day')
g.fig.suptitle("pairplot of tips Dataset", y=1.02)
g.set(xticks=[], yticks=[])
plt.show()
